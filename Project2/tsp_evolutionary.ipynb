# %% [markdown]
# # Pseudocode

# %% [markdown]
# ```text
# FUNCTION load_tsp_data(name_file, distance_file):
#     distance_matrix = []
#     READ in name_file
#     READ in distance_file
#     APPEND distances to distance_matrix
#
# FUNCTION fitness(route, distance_matrix):
#     total_distance = 0
#     FOR i from 0 to length(route) - 1:
#         total_distance += total_distance + distance_matrix[route[i]][route[i+1]]
#     total_distance = total_distance + distance_matrix[route[-1]][route[0]]
#
#     RETURN total_distance
#
# FUNCTION mutate(parent_route):
#     copy_route = make a copy of the route
#     i, j = randomly select 2 different indices from copy_route
#     SWAP i,j
#
#     RETURN copy_route
#
# FUNCTION tsp_evolutionary(name_file, distance_file):
#     city_names = list of city names from name_file
#     distance_matrix = list of distances from distance_file
#     best_route = [0,1,2,3,...,n-1]
#     best_distance = fitness(best_route,distance_matrix)
#     Print "Initial Route Distance:", best_distance, best_route
#
#     same_count = 0
#     generation = 1
#     WHILE same_count < 3:
#
#         parent_route = best_route
#         parent_distance = best_distance
#
#         improvement_found = FALSE
#         best_offspring = parent_route
#         best_offspring_distance = parent_distance
#
#             FOR offspring_number from 1 to 50:
#                 offspring = mutate(best_route)
#                 offspring_distance = fitness(offspring,distance_matrix)
#
#                 IF offspring_distance < best_distance:
#                     best_route = offspring
#                     best_distance = offspring_distance
#                     improvement_found = TRUE
#             PRINT "Generation:", generation, "Best Distance:", best_distance, "Route:", best_route
#
#             IF improvement_found == TRUE
#                 same_count = 0
#             ELSE:
#                 same_count += 1
#                 IF same_count < 3:
#                     FOR k from 1 to 8:
#                         best_route = mutate(best_route)
#             generation += 1
#
#     PRINT "Terminated after", generation, "generations."
#     PRINT "Final Best Route Distance:", best_distance
#     RETURN best_route

# %%
import random

# %%
def load_tsp_data(name_file, distance_file):
    """
    Load tsp city names and distance matrrix from files

    Parameters 
    name_file: text file including city names
    distance_file: text file including distances between cities

    Returns
    city_names: list of city names
    distance_matrix = list of distances between cities
    """

    # Load city names into a list 
    with open(name_file, "r") as f:
        city_names = [line.strip() for line in f if line.strip()]

    # Create empty list 
    distance_matrix = []
    with open(distance_file, "r") as f:
        for line in f:
            if line.strip():
                # split the line by spaces and convert each value to float
                distance_matrix.append([float(x) for x in line.strip().split()])

    # Return both lists for other functions to use
    return city_names, distance_matrix

# %%
def fitness(route,distance_matrix):
    """
    Calculate total distance of a route 

    Parameters
    route: list of integers
    distance_matrix: list 
    
    Returns
    total_distance: float of the total travel distance
    """
    total_distance = 0
    # Add distance between each pair of consecutive cities
    for i in range(len(route)-1):
        total_distance += distance_matrix[route[i]][route[i + 1]]
    # Add distance returning from final city back to starting city
    total_distance += distance_matrix[route[-1]][route[0]]
    
    return total_distance

# %%
def mutate(parent_route):
    """
    Create an offspring route by swapping two cities in a copy of the parent

    Paremeters
    parent_route: list of integers, current best route

    Returns
    new_route: list of integers, new route created by swapping two random cities
    """

    # Make copy so original parent_route isn't changed
    new_route = parent_route.copy()

    # Randomly select two positions in the route to swap
    i,j = random.sample(range(len(parent_route)), 2)

    # Swap the cities at the two randomly select postions
    new_route[i], new_route[j] = new_route[j], new_route[i]
    
    return new_route

# %%
def tsp_evolution(name_file, distance_file):
    """
    Solve the TSP using evolutionary

    Parameters
    name_file: file containing name of cities
    distance_file: file containing distances between cities

    Prints
    Intial Route, the initial route between the cities 
    Generation, the best route found in that generation as city names, and total distance
    Final Route, the best route found within each generation as city names, and total distance

    Returns
    overall_best_route: the best route found within the generations as indexes.
    """

    # Load city names and distance data
    city_names, distance_matrix = load_tsp_data(name_file, distance_file)
    num_cities = len(city_names)

    # Starting route in city order
    best_route = list(range(num_cities))
    best_distance = fitness(best_route, distance_matrix)

    # Tracks the best route found across all generations
    overall_best_route = best_route.copy()
    overall_best_distance = best_distance

    # Print intial route using city names
    initial_route_names = [city_names[i] for i in best_route]
    print("Initial Route Distance:", round(best_distance, 2), initial_route_names)

    same_count = 0 # how many generations had no improvement
    generation = 1 # generation counter
    max_generations = 1000 # max number of generations allowed

    # Evolve until stagnation or maxx generations is reached
    while same_count < 3 and generation <= max_generations:

        # Use the current best route as parent route
        parent_route = best_route
        parent_distance = best_distance

        improvement_found = False
        best_offspring = parent_route
        best_offspring_distance = parent_distance

        num_offspring = 1000 # number of offspring per generation

        # Create offspring and record the best one
        for i in range(num_offspring):
            offspring = mutate(parent_route)
            offspring_distance = fitness(offspring, distance_matrix)

            if offspring_distance < best_offspring_distance:
                best_offspring = offspring
                best_offspring_distance = offspring_distance
                improvement_found = True
        
        # Print best route of the generation in names
        best_offspring_names = [city_names[i] for i in best_offspring]
        print(f"Generation {generation}: {best_offspring_names} | Distance = {round(best_offspring_distance, 2)}")

        # Update parent route if improvement ocurred
        if improvement_found:
            best_route = best_offspring
            best_distance = best_offspring_distance
            same_count = 0

            # Update global best 
            if best_distance < overall_best_distance:
                overall_best_route = best_route.copy()
                overall_best_distance = best_distance
        else:
            # No improvement found
            same_count += 1
            if same_count < 3:
                print("No improvement")

                # Force mutate the route 5 times to escape local minimum
                for i in range(5):
                    best_route = mutate(best_route)
                best_distance = fitness(best_route,distance_matrix)

        generation += 1

    # Convert best final route to city names
    route_names = [city_names[i] for i in best_route]

    # Print results
    print("\nTerminated after", generation, "generations.")
    print("Final Best Route:", route_names)
    print("Final Distance:", round(overall_best_distance, 2))

    return overall_best_route

# %%
tsp_evolution("thirty_cities_names.txt", "thirty_cities_dist.txt")
# Out:
# Initial Route Distance: 1616.0 ['Azores', 'Baghdad', 'Berlin', 'Bombay', 'Buenos Aires', 'Cairo', 'Capetown', 'Chicago', 'Guam', 'Honolulu', 'Istanbul', 'Juneau', 'London', 'Manila', 'Melbourne', 'Mexico City', 'Montreal', 'Moscow', 'New Orleans', 'New York', 'Panama City', 'Paris', 'Rio de Janeiro', 'Rome', 'San Francisco', 'Santiago', 'Seattle', 'Shanghai', 'Sydney', 'Tokyo']
# Generation 1: ['Azores', 'Baghdad', 'Berlin', 'Bombay', 'Buenos Aires', 'Cairo', 'Capetown', 'Chicago', 'Guam', 'Honolulu', 'Istanbul', 'Moscow', 'London', 'Manila', 'Melbourne', 'Mexico City', 'Montreal', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Paris', 'Rio de Janeiro', 'Rome', 'San Francisco', 'Santiago', 'Seattle', 'Shanghai', 'Sydney', 'Tokyo'] | Distance = 1497.0
# Generation 2: ['Azores', 'Baghdad', 'Berlin', 'Bombay', 'Paris', 'Cairo', 'Capetown', 'Chicago', 'Guam', 'Honolulu', 'Istanbul', 'Moscow', 'London', 'Manila', 'Melbourne', 'Mexico City', 'Montreal', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Rome', 'San Francisco', 'Santiago', 'Seattle', 'Shanghai', 'Sydney', 'Tokyo'] | Distance = 1329.0
# Generation 3: ['Azores', 'Baghdad', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Chicago', 'Guam', 'Honolulu', 'Istanbul', 'Moscow', 'Bombay', 'Manila', 'Melbourne', 'Mexico City', 'Montreal', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Rome', 'San Francisco', 'Santiago', 'Seattle', 'Shanghai', 'Sydney', 'Tokyo'] | Distance = 1235.0
# Generation 4: ['Azores', 'Baghdad', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Santiago', 'Guam', 'Honolulu', 'Istanbul', 'Moscow', 'Bombay', 'Manila', 'Melbourne', 'Mexico City', 'Montreal', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Rome', 'San Francisco', 'Chicago', 'Seattle', 'Shanghai', 'Sydney', 'Tokyo'] | Distance = 1136.0
# Generation 5: ['Azores', 'Baghdad', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Guam', 'Honolulu', 'Istanbul', 'Moscow', 'Bombay', 'Manila', 'Melbourne', 'Mexico City', 'Montreal', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'San Francisco', 'Chicago', 'Seattle', 'Shanghai', 'Sydney', 'Tokyo'] | Distance = 1074.0
# Generation 6: ['Azores', 'Baghdad', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Guam', 'Honolulu', 'Istanbul', 'Moscow', 'Bombay', 'Sydney', 'Melbourne', 'Mexico City', 'Montreal', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'San Francisco', 'Chicago', 'Seattle', 'Shanghai', 'Manila', 'Tokyo'] | Distance = 1004.0
# Generation 7: ['Guam', 'Baghdad', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Azores', 'Honolulu', 'Istanbul', 'Moscow', 'Bombay', 'Sydney', 'Melbourne', 'Mexico City', 'Montreal', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'San Francisco', 'Chicago', 'Seattle', 'Shanghai', 'Manila', 'Tokyo'] | Distance = 951.0
# Generation 8: ['Guam', 'Moscow', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Azores', 'Honolulu', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Mexico City', 'Montreal', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'San Francisco', 'Chicago', 'Seattle', 'Shanghai', 'Manila', 'Tokyo'] | Distance = 926.0
# Generation 9: ['Guam', 'Honolulu', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Azores', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Mexico City', 'Montreal', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'San Francisco', 'Chicago', 'Seattle', 'Shanghai', 'Manila', 'Tokyo'] | Distance = 855.0
# Generation 10: ['Guam', 'Honolulu', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Azores', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Mexico City', 'San Francisco', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Shanghai', 'Manila', 'Tokyo'] | Distance = 824.0
# Generation 11: ['Guam', 'Shanghai', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Azores', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Mexico City', 'San Francisco', 'Juneau', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Honolulu', 'Manila', 'Tokyo'] | Distance = 794.0
# Generation 12: ['Guam', 'Shanghai', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Azores', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Juneau', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Honolulu', 'Manila', 'Tokyo'] | Distance = 771.0
# Generation 13: ['Manila', 'Shanghai', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Azores', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Juneau', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Honolulu', 'Guam', 'Tokyo'] | Distance = 749.0
# Generation 14: ['Manila', 'Shanghai', 'Berlin', 'London', 'Paris', 'Cairo', 'Capetown', 'Rome', 'Azores', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Juneau', 'Guam', 'Tokyo'] | Distance = 727.0
# Generation 15: ['Manila', 'Shanghai', 'Berlin', 'London', 'Paris', 'Azores', 'Capetown', 'Rome', 'Cairo', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Juneau', 'Guam', 'Tokyo'] | Distance = 713.0
# Generation 16: ['Manila', 'Shanghai', 'Berlin', 'London', 'Paris', 'Azores', 'Capetown', 'Rome', 'Cairo', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 699.0
# Generation 17: ['Manila', 'Shanghai', 'Berlin', 'London', 'Paris', 'Azores', 'Capetown', 'Rome', 'Cairo', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Sydney', 'Melbourne', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 688.0
# Generation 18: ['Manila', 'Shanghai', 'Berlin', 'London', 'Paris', 'Azores', 'Capetown', 'Rome', 'Cairo', 'Moscow', 'Istanbul', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 682.0
# Generation 19: ['Manila', 'Shanghai', 'Berlin', 'London', 'Paris', 'Azores', 'Capetown', 'Rome', 'Istanbul', 'Moscow', 'Cairo', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 676.0
# Generation 20: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Rome', 'Istanbul', 'Moscow', 'Cairo', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Montreal', 'Chicago', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 675.0
# Generation 21: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Rome', 'Istanbul', 'Moscow', 'Cairo', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'New Orleans', 'Chicago', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 671.0
# Generation 22: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Moscow', 'Rome', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'New Orleans', 'Chicago', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 670.0
# Generation 23: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Moscow', 'Rome', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'New Orleans', 'Mexico City', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 662.0
# Generation 24: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'New Orleans', 'Mexico City', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 658.0
# Generation 25: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'New Orleans', 'Mexico City', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 658.0
# No improvement
# Generation 26: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Seattle', 'Chicago', 'Montreal', 'Buenos Aires', 'Panama City', 'Rio de Janeiro', 'New York', 'Honolulu', 'Tokyo', 'Mexico City', 'San Francisco', 'Juneau', 'New Orleans', 'Guam'] | Distance = 966.0
# Generation 27: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Seattle', 'Chicago', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Honolulu', 'Tokyo', 'Mexico City', 'San Francisco', 'Juneau', 'New Orleans', 'Guam'] | Distance = 892.0
# Generation 28: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Mexico City', 'Chicago', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Honolulu', 'Tokyo', 'Seattle', 'San Francisco', 'Juneau', 'New Orleans', 'Guam'] | Distance = 835.0
# Generation 29: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Mexico City', 'New Orleans', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Honolulu', 'Tokyo', 'Seattle', 'San Francisco', 'Juneau', 'Chicago', 'Guam'] | Distance = 824.0
# Generation 30: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Mexico City', 'New Orleans', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Chicago', 'Tokyo', 'Seattle', 'San Francisco', 'Juneau', 'Honolulu', 'Guam'] | Distance = 797.0
# Generation 31: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Mexico City', 'New Orleans', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Chicago', 'San Francisco', 'Seattle', 'Tokyo', 'Juneau', 'Honolulu', 'Guam'] | Distance = 778.0
# Generation 32: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Mexico City', 'New Orleans', 'Montreal', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Chicago', 'San Francisco', 'Seattle', 'Honolulu', 'Juneau', 'Tokyo', 'Guam'] | Distance = 735.0
# Generation 33: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Mexico City', 'New Orleans', 'Montreal', 'New York', 'Chicago', 'Rio de Janeiro', 'Buenos Aires', 'Panama City', 'San Francisco', 'Seattle', 'Honolulu', 'Juneau', 'Tokyo', 'Guam'] | Distance = 731.0
# Generation 34: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Mexico City', 'New Orleans', 'Montreal', 'New York', 'Chicago', 'Rio de Janeiro', 'Buenos Aires', 'Panama City', 'San Francisco', 'Honolulu', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 729.0
# Generation 35: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Santiago', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Panama City', 'San Francisco', 'Honolulu', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 721.0
# Generation 36: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Panama City', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'San Francisco', 'Honolulu', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 712.0
# Generation 37: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Panama City', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Honolulu', 'San Francisco', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 702.0
# Generation 38: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'San Francisco', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 659.0
# Generation 39: ['Manila', 'Shanghai', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'San Francisco', 'Seattle', 'Juneau', 'Tokyo', 'Guam'] | Distance = 659.0
# No improvement
# Generation 40: ['Manila', 'Shanghai', 'Berlin', 'Istanbul', 'London', 'Azores', 'Capetown', 'Cairo', 'Panama City', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Paris', 'Santiago', 'San Francisco', 'Seattle', 'Tokyo', 'Juneau', 'Guam'] | Distance = 995.0
# Generation 41: ['Manila', 'Shanghai', 'Berlin', 'Istanbul', 'London', 'Paris', 'Capetown', 'Cairo', 'Panama City', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Azores', 'Santiago', 'San Francisco', 'Seattle', 'Tokyo', 'Juneau', 'Guam'] | Distance = 952.0
# Generation 42: ['Manila', 'Shanghai', 'Berlin', 'Istanbul', 'London', 'Paris', 'Capetown', 'Cairo', 'Azores', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Panama City', 'Santiago', 'San Francisco', 'Seattle', 'Tokyo', 'Juneau', 'Guam'] | Distance = 829.0
# Generation 43: ['Manila', 'Shanghai', 'Berlin', 'Istanbul', 'London', 'Paris', 'Capetown', 'Cairo', 'Azores', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'San Francisco', 'Seattle', 'Tokyo', 'Juneau', 'Guam'] | Distance = 790.0
# Generation 44: ['Manila', 'Shanghai', 'Berlin', 'Azores', 'London', 'Paris', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'San Francisco', 'Seattle', 'Tokyo', 'Juneau', 'Guam'] | Distance = 764.0
# Generation 45: ['Manila', 'Juneau', 'Berlin', 'Azores', 'London', 'Paris', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'Mexico City', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'San Francisco', 'Seattle', 'Tokyo', 'Shanghai', 'Guam'] | Distance = 745.0
# Generation 46: ['Manila', 'Juneau', 'Berlin', 'Azores', 'London', 'Paris', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'Mexico City', 'Seattle', 'Tokyo', 'Shanghai', 'Guam'] | Distance = 739.0
# Generation 47: ['Manila', 'Juneau', 'Azores', 'Berlin', 'London', 'Paris', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Panama City', 'Buenos Aires', 'Rio de Janeiro', 'Santiago', 'Mexico City', 'Seattle', 'Tokyo', 'Shanghai', 'Guam'] | Distance = 729.0
# Generation 48: ['Manila', 'Juneau', 'Azores', 'Berlin', 'London', 'Paris', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Panama City', 'Mexico City', 'Seattle', 'Tokyo', 'Shanghai', 'Guam'] | Distance = 721.0
# Generation 49: ['Manila', 'Juneau', 'Azores', 'Berlin', 'London', 'Paris', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Tokyo', 'Shanghai', 'Guam'] | Distance = 716.0
# Generation 50: ['Manila', 'Juneau', 'Azores', 'Paris', 'London', 'Berlin', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Tokyo', 'Shanghai', 'Guam'] | Distance = 712.0
# Generation 51: ['Manila', 'Tokyo', 'Azores', 'Paris', 'London', 'Berlin', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Shanghai', 'Guam'] | Distance = 698.0
# Generation 52: ['Manila', 'Tokyo', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Shanghai', 'Guam'] | Distance = 677.0
# Generation 53: ['Manila', 'Tokyo', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Shanghai'] | Distance = 675.0
# Generation 54: ['Shanghai', 'Tokyo', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 664.0
# Generation 55: ['Shanghai', 'Tokyo', 'Berlin', 'Paris', 'London', 'Azores', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 664.0
# No improvement
# Generation 56: ['Shanghai', 'Tokyo', 'Paris', 'Buenos Aires', 'London', 'Berlin', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Manila', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Azores', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Sydney'] | Distance = 965.0
# Generation 57: ['Shanghai', 'Tokyo', 'Paris', 'Buenos Aires', 'London', 'Berlin', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Azores', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 874.0
# Generation 58: ['Shanghai', 'Tokyo', 'Paris', 'Azores', 'London', 'Berlin', 'Capetown', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 687.0
# Generation 59: ['Shanghai', 'Tokyo', 'Capetown', 'Azores', 'London', 'Berlin', 'Paris', 'Cairo', 'Istanbul', 'Rome', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 679.0
# Generation 60: ['Shanghai', 'Tokyo', 'Capetown', 'Azores', 'London', 'Berlin', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Moscow', 'Baghdad', 'Bombay', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 669.0
# Generation 61: ['Shanghai', 'Tokyo', 'Bombay', 'Azores', 'London', 'Berlin', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Moscow', 'Baghdad', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 653.0
# Generation 62: ['Shanghai', 'Tokyo', 'Moscow', 'Azores', 'London', 'Berlin', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Bombay', 'Baghdad', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 644.0
# Generation 63: ['Shanghai', 'Tokyo', 'Moscow', 'Azores', 'London', 'Berlin', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 627.0
# Generation 64: ['Shanghai', 'Tokyo', 'Moscow', 'Azores', 'London', 'Berlin', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Seattle', 'Juneau', 'Guam', 'Manila'] | Distance = 627.0
# No improvement
# Generation 65: ['Shanghai', 'Seattle', 'Manila', 'Berlin', 'London', 'Moscow', 'Paris', 'Istanbul', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Azores', 'Juneau', 'Guam', 'Tokyo'] | Distance = 803.0
# Generation 66: ['Shanghai', 'Guam', 'Manila', 'Berlin', 'London', 'Moscow', 'Paris', 'Istanbul', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Montreal', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Azores', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 704.0
# Generation 67: ['Shanghai', 'Guam', 'Manila', 'Berlin', 'London', 'Moscow', 'Paris', 'Istanbul', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Chicago', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Montreal', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 676.0
# Generation 68: ['Shanghai', 'Guam', 'Manila', 'Berlin', 'London', 'Moscow', 'Paris', 'Istanbul', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Montreal', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 669.0
# Generation 69: ['Shanghai', 'Guam', 'Manila', 'Berlin', 'London', 'Moscow', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Montreal', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 657.0
# Generation 70: ['Shanghai', 'Guam', 'Manila', 'Moscow', 'London', 'Berlin', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Montreal', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 636.0
# Generation 71: ['Manila', 'Guam', 'Shanghai', 'Moscow', 'London', 'Berlin', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Montreal', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 635.0
# Generation 72: ['Manila', 'Guam', 'Shanghai', 'Moscow', 'London', 'Berlin', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Montreal', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 621.0
# Generation 73: ['Manila', 'Guam', 'Shanghai', 'Moscow', 'London', 'Paris', 'Berlin', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Montreal', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 617.0
# Generation 74: ['Manila', 'Guam', 'Shanghai', 'Moscow', 'Berlin', 'Paris', 'London', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Montreal', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 613.0
# Generation 75: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'Paris', 'London', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'Montreal', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 603.0
# Generation 76: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'Paris', 'London', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'New York', 'Montreal', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 600.0
# Generation 77: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'New York', 'Montreal', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 599.0
# Generation 78: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'New York', 'Montreal', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 599.0
# No improvement
# Generation 79: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Azores', 'Juneau', 'Istanbul', 'Cairo', 'New York', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Seattle', 'San Francisco', 'New Orleans', 'Baghdad', 'Montreal', 'Paris', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Honolulu', 'Rome', 'Tokyo'] | Distance = 1070.0
# Generation 80: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Azores', 'Baghdad', 'Istanbul', 'Cairo', 'New York', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Seattle', 'San Francisco', 'New Orleans', 'Juneau', 'Montreal', 'Paris', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Honolulu', 'Rome', 'Tokyo'] | Distance = 943.0
# Generation 81: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Azores', 'Baghdad', 'Istanbul', 'Cairo', 'New York', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Seattle', 'San Francisco', 'Honolulu', 'Juneau', 'Montreal', 'Paris', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'New Orleans', 'Rome', 'Tokyo'] | Distance = 887.0
# Generation 82: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Azores', 'New York', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Seattle', 'San Francisco', 'Honolulu', 'Juneau', 'Montreal', 'Paris', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'New Orleans', 'Rome', 'Tokyo'] | Distance = 807.0
# Generation 83: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Azores', 'Paris', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Seattle', 'San Francisco', 'Honolulu', 'Juneau', 'Montreal', 'New York', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'New Orleans', 'Rome', 'Tokyo'] | Distance = 722.0
# Generation 84: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Azores', 'Paris', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Seattle', 'Juneau', 'Montreal', 'New York', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'New Orleans', 'Rome', 'Tokyo'] | Distance = 677.0
# Generation 85: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Rome', 'Paris', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Seattle', 'Juneau', 'Montreal', 'New York', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'New Orleans', 'Azores', 'Tokyo'] | Distance = 654.0
# Generation 86: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Rome', 'Paris', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Seattle', 'Azores', 'Montreal', 'New York', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'New Orleans', 'Juneau', 'Tokyo'] | Distance = 649.0
# Generation 87: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Rome', 'Paris', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Seattle', 'Azores', 'Montreal', 'New York', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'Chicago', 'Juneau', 'Tokyo'] | Distance = 635.0
# Generation 88: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Seattle', 'Azores', 'Montreal', 'New York', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'Chicago', 'Juneau', 'Tokyo'] | Distance = 623.0
# Generation 89: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Seattle', 'Azores', 'Montreal', 'New York', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'Chicago', 'Juneau', 'Tokyo'] | Distance = 623.0
# No improvement
# Generation 90: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'New York', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Azores', 'Seattle', 'Juneau', 'New Orleans', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'London', 'Chicago', 'Montreal', 'Tokyo'] | Distance = 834.0
# Generation 91: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'New York', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'Seattle', 'Juneau', 'New Orleans', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'London', 'Azores', 'Montreal', 'Tokyo'] | Distance = 766.0
# Generation 92: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'New York', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'Seattle', 'Juneau', 'London', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'Azores', 'Montreal', 'Tokyo'] | Distance = 763.0
# Generation 93: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'Azores', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'Seattle', 'Juneau', 'London', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'New York', 'Montreal', 'Tokyo'] | Distance = 680.0
# Generation 94: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'Seattle', 'Juneau', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'New York', 'Montreal', 'Tokyo'] | Distance = 638.0
# Generation 95: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Juneau', 'Seattle', 'Chicago', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'New York', 'Montreal', 'Tokyo'] | Distance = 620.0
# Generation 96: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Juneau', 'Seattle', 'Chicago', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'New York', 'Montreal', 'Tokyo'] | Distance = 620.0
# No improvement
# Generation 97: ['Guam', 'Manila', 'Shanghai', 'Melbourne', 'Moscow', 'London', 'Paris', 'Rome', 'Berlin', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Panama City', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'Azores', 'Chicago', 'Seattle', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Istanbul', 'Juneau', 'New Orleans', 'New York', 'Montreal', 'Tokyo'] | Distance = 992.0
# Generation 98: ['Guam', 'Manila', 'Shanghai', 'Melbourne', 'Moscow', 'London', 'Paris', 'Rome', 'Berlin', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Istanbul', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'Azores', 'Chicago', 'Seattle', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Juneau', 'New Orleans', 'New York', 'Montreal', 'Tokyo'] | Distance = 919.0
# Generation 99: ['Guam', 'Manila', 'Shanghai', 'Istanbul', 'Moscow', 'London', 'Paris', 'Rome', 'Berlin', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'Azores', 'Chicago', 'Seattle', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Juneau', 'New Orleans', 'New York', 'Montreal', 'Tokyo'] | Distance = 762.0
# Generation 100: ['Guam', 'Manila', 'Shanghai', 'Istanbul', 'Moscow', 'London', 'Paris', 'Rome', 'Berlin', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'Azores', 'Chicago', 'New Orleans', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Juneau', 'Seattle', 'New York', 'Montreal', 'Tokyo'] | Distance = 724.0
# Generation 101: ['Guam', 'Manila', 'Shanghai', 'Istanbul', 'Moscow', 'London', 'Paris', 'Berlin', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'Azores', 'Chicago', 'New Orleans', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Juneau', 'Seattle', 'New York', 'Montreal', 'Tokyo'] | Distance = 717.0
# Generation 102: ['Guam', 'Manila', 'Shanghai', 'Istanbul', 'Moscow', 'London', 'Paris', 'Berlin', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Chicago', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Juneau', 'Seattle', 'New York', 'Montreal', 'Tokyo'] | Distance = 676.0
# Generation 103: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'London', 'Paris', 'Berlin', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Chicago', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Juneau', 'Seattle', 'New York', 'Montreal', 'Tokyo'] | Distance = 669.0
# Generation 104: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'Paris', 'London', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Chicago', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Juneau', 'Seattle', 'New York', 'Montreal', 'Tokyo'] | Distance = 666.0
# Generation 105: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'Paris', 'London', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Juneau', 'Seattle', 'Chicago', 'Montreal', 'Tokyo'] | Distance = 661.0
# Generation 106: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'Paris', 'London', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Chicago', 'Seattle', 'Juneau', 'Montreal', 'Tokyo'] | Distance = 657.0
# Generation 107: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'Paris', 'London', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Chicago', 'Montreal', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 631.0
# Generation 108: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'Paris', 'London', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Chicago', 'Montreal', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 620.0
# Generation 109: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Chicago', 'Montreal', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 619.0
# Generation 110: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Montreal', 'Chicago', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 615.0
# Generation 111: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Montreal', 'Chicago', 'Seattle', 'Juneau', 'Tokyo'] | Distance = 615.0
# No improvement
# Generation 112: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'San Francisco', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'Cairo', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Chicago', 'Buenos Aires', 'Santiago', 'Panama City', 'Montreal', 'Rio de Janeiro', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 972.0
# Generation 113: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Cairo', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Chicago', 'Buenos Aires', 'Santiago', 'Panama City', 'Montreal', 'Rio de Janeiro', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 770.0
# Generation 114: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Cairo', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'New York', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Montreal', 'Chicago', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 641.0
# Generation 115: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Cairo', 'Berlin', 'London', 'Paris', 'Rome', 'Istanbul', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Montreal', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'New York', 'Chicago', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 638.0
# Generation 116: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Montreal', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'New York', 'Chicago', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 626.0
# Generation 117: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Mexico City', 'New York', 'Montreal', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'New Orleans', 'Chicago', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 622.0
# Generation 118: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'New Orleans', 'New York', 'Montreal', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'Chicago', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 621.0
# Generation 119: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'New York', 'Montreal', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 614.0
# Generation 120: ['Guam', 'Manila', 'Shanghai', 'Moscow', 'Istanbul', 'Berlin', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Bombay', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'New York', 'Montreal', 'Azores', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'Mexico City', 'New Orleans', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 614.0
# No improvement
# Generation 121: ['Guam', 'Paris', 'Berlin', 'Moscow', 'Istanbul', 'Montreal', 'London', 'Manila', 'Rome', 'Cairo', 'Baghdad', 'Panama City', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'New York', 'Santiago', 'Mexico City', 'Rio de Janeiro', 'Buenos Aires', 'Shanghai', 'Bombay', 'Azores', 'New Orleans', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 1155.0
# Generation 122: ['Guam', 'Manila', 'Berlin', 'Moscow', 'Istanbul', 'Montreal', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Panama City', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'New York', 'Santiago', 'Mexico City', 'Rio de Janeiro', 'Buenos Aires', 'Shanghai', 'Bombay', 'Azores', 'New Orleans', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 1028.0
# Generation 123: ['Guam', 'Manila', 'Berlin', 'Moscow', 'Istanbul', 'Montreal', 'London', 'Paris', 'Rome', 'Cairo', 'Baghdad', 'Panama City', 'Capetown', 'Melbourne', 'Sydney', 'Honolulu', 'San Francisco', 'Chicago', 'New York', 'Santiago', 'Mexico City', 'Rio de Janeiro', 'Buenos Aires', 'Azores', 'Bombay', 'Shanghai', 'New Orleans', 'Juneau', 'Seattle', 'Tokyo'] | Distance = 1001.0
# ...
# Generation 962: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Istanbul', 'Rome', 'Berlin', 'Juneau', 'San Francisco', 'Montreal', 'New York', 'Panama City', 'Santiago', 'Rio de Janeiro', 'Buenos Aires', 'Mexico City', 'New Orleans', 'London', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'Seattle', 'Chicago', 'Azores', 'Paris', 'Cairo', 'Baghdad', 'Bombay'] | Distance = 738.0
# Generation 963: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Berlin', 'Juneau', 'San Francisco', 'Montreal', 'New York', 'Panama City', 'Santiago', 'Rio de Janeiro', 'Buenos Aires', 'Mexico City', 'New Orleans', 'London', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'Seattle', 'Chicago', 'Azores', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 731.0
# Generation 964: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'San Francisco', 'Montreal', 'New York', 'Panama City', 'Santiago', 'Rio de Janeiro', 'Buenos Aires', 'Mexico City', 'New Orleans', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'Seattle', 'Chicago', 'Azores', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 730.0
# Generation 965: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'San Francisco', 'Montreal', 'New York', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Mexico City', 'New Orleans', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'Seattle', 'Chicago', 'Azores', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 721.0
# Generation 966: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'Seattle', 'Montreal', 'New York', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Mexico City', 'New Orleans', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'San Francisco', 'Chicago', 'Azores', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 712.0
# Generation 967: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'Seattle', 'Chicago', 'New York', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Mexico City', 'New Orleans', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'San Francisco', 'Montreal', 'Azores', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 708.0
# Generation 968: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'Seattle', 'Chicago', 'New York', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Mexico City', 'New Orleans', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'San Francisco', 'Montreal', 'Azores', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 703.0
# Generation 969: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Panama City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Mexico City', 'New York', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'San Francisco', 'Montreal', 'Azores', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 699.0
# Generation 970: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Mexico City', 'Rio de Janeiro', 'Buenos Aires', 'Santiago', 'Panama City', 'New York', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'San Francisco', 'Montreal', 'Azores', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 698.0
# Generation 971: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Mexico City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Panama City', 'New York', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'San Francisco', 'Montreal', 'Azores', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 693.0
# Generation 972: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Mexico City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Panama City', 'Azores', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'San Francisco', 'Montreal', 'New York', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 690.0
# Generation 973: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'London', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Mexico City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Panama City', 'Azores', 'Berlin', 'Moscow', 'Shanghai', 'Tokyo', 'Honolulu', 'San Francisco', 'Montreal', 'New York', 'Paris', 'Istanbul', 'Baghdad', 'Bombay'] | Distance = 690.0
# No improvement
# Generation 974: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Panama City', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Mexico City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Moscow', 'Shanghai', 'Baghdad', 'Honolulu', 'San Francisco', 'Montreal', 'New York', 'Azores', 'Istanbul', 'Tokyo', 'Bombay'] | Distance = 863.0
# Generation 975: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Panama City', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Mexico City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Moscow', 'Istanbul', 'Baghdad', 'Honolulu', 'San Francisco', 'Montreal', 'New York', 'Azores', 'Shanghai', 'Tokyo', 'Bombay'] | Distance = 796.0
# Generation 976: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Panama City', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Mexico City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Moscow', 'Istanbul', 'Baghdad', 'Honolulu', 'San Francisco', 'Montreal', 'New York', 'Azores', 'Bombay', 'Tokyo', 'Shanghai'] | Distance = 763.0
# Generation 977: ['Manila', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Mexico City', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Moscow', 'Istanbul', 'Baghdad', 'Honolulu', 'San Francisco', 'Montreal', 'New York', 'Azores', 'Bombay', 'Tokyo', 'Shanghai'] | Distance = 752.0
# Generation 978: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Mexico City', 'Juneau', 'Seattle', 'Chicago', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Moscow', 'Istanbul', 'Baghdad', 'Honolulu', 'San Francisco', 'Montreal', 'New York', 'Azores', 'Bombay', 'Manila', 'Shanghai'] | Distance = 742.0
# Generation 979: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Mexico City', 'Honolulu', 'Seattle', 'Chicago', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Moscow', 'Istanbul', 'Baghdad', 'Juneau', 'San Francisco', 'Montreal', 'New York', 'Azores', 'Bombay', 'Manila', 'Shanghai'] | Distance = 734.0
# Generation 980: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Mexico City', 'Honolulu', 'Seattle', 'San Francisco', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Moscow', 'Istanbul', 'Baghdad', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Azores', 'Bombay', 'Manila', 'Shanghai'] | Distance = 726.0
# Generation 981: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'San Francisco', 'Honolulu', 'Seattle', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Moscow', 'Istanbul', 'Baghdad', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Azores', 'Bombay', 'Manila', 'Shanghai'] | Distance = 717.0
# Generation 982: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Seattle', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Moscow', 'Istanbul', 'Baghdad', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Azores', 'Bombay', 'Manila', 'Shanghai'] | Distance = 707.0
# Generation 983: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Rome', 'Seattle', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Baghdad', 'Istanbul', 'Moscow', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Azores', 'Bombay', 'Manila', 'Shanghai'] | Distance = 702.0
# Generation 984: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Seattle', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Azores', 'Bombay', 'Manila', 'Shanghai'] | Distance = 694.0
# Generation 985: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Honolulu', 'Seattle', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Paris', 'London', 'Berlin', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Azores', 'Bombay', 'Manila', 'Shanghai'] | Distance = 693.0
# Generation 986: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Honolulu', 'Seattle', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Berlin', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Paris', 'Bombay', 'Manila', 'Shanghai'] | Distance = 689.0
# Generation 987: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Honolulu', 'Seattle', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 684.0
# Generation 988: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Honolulu', 'Seattle', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 684.0
# No improvement
# Generation 989: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Paris', 'Cairo', 'Baghdad', 'Honolulu', 'Chicago', 'Capetown', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Rio de Janeiro', 'Buenos Aires', 'Azores', 'London', 'San Francisco', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Seattle', 'Montreal', 'New York', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 990.0
# Generation 990: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Honolulu', 'Chicago', 'Paris', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Rio de Janeiro', 'Buenos Aires', 'Azores', 'London', 'San Francisco', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Seattle', 'Montreal', 'New York', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 903.0
# Generation 991: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Honolulu', 'Chicago', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Rio de Janeiro', 'Buenos Aires', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Seattle', 'Montreal', 'New York', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 735.0
# Generation 992: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Honolulu', 'Chicago', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Seattle', 'Montreal', 'New York', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 713.0
# Generation 993: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Chicago', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Seattle', 'Montreal', 'New York', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 698.0
# Generation 994: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Seattle', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Chicago', 'Montreal', 'New York', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 685.0
# Generation 995: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Seattle', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Juneau', 'Chicago', 'New York', 'Montreal', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 681.0
# Generation 996: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Baghdad', 'Juneau', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Seattle', 'Chicago', 'New York', 'Montreal', 'Berlin', 'Bombay', 'Manila', 'Shanghai'] | Distance = 675.0
# Generation 997: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Berlin', 'Juneau', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Seattle', 'Chicago', 'New York', 'Montreal', 'Baghdad', 'Bombay', 'Manila', 'Shanghai'] | Distance = 672.0
# Generation 998: ['Tokyo', 'Guam', 'Sydney', 'Melbourne', 'Capetown', 'Cairo', 'Berlin', 'Juneau', 'Honolulu', 'San Francisco', 'Mexico City', 'New Orleans', 'Panama City', 'Santiago', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Istanbul', 'Moscow', 'Seattle', 'Chicago', 'New York', 'Montreal', 'Baghdad', 'Bombay', 'Manila', 'Shanghai'] | Distance = 672.0
# No improvement
# Generation 999: ['Santiago', 'Honolulu', 'New Orleans', 'Melbourne', 'Shanghai', 'Cairo', 'Berlin', 'Juneau', 'Panama City', 'San Francisco', 'Mexico City', 'Sydney', 'Guam', 'Tokyo', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Baghdad', 'Moscow', 'Seattle', 'Chicago', 'New York', 'Montreal', 'Istanbul', 'Bombay', 'Manila', 'Capetown'] | Distance = 1138.0
# Generation 1000: ['Santiago', 'Honolulu', 'New Orleans', 'Mexico City', 'Shanghai', 'Cairo', 'Berlin', 'Juneau', 'Panama City', 'San Francisco', 'Melbourne', 'Sydney', 'Guam', 'Tokyo', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Baghdad', 'Moscow', 'Seattle', 'Chicago', 'New York', 'Montreal', 'Istanbul', 'Bombay', 'Manila', 'Capetown'] | Distance = 1067.0
#
# Terminated after 1001 generations.
# Final Best Route: ['Santiago', 'Honolulu', 'New Orleans', 'Mexico City', 'Shanghai', 'Cairo', 'Berlin', 'Juneau', 'Panama City', 'San Francisco', 'Melbourne', 'Sydney', 'Guam', 'Tokyo', 'Buenos Aires', 'Rio de Janeiro', 'Azores', 'London', 'Paris', 'Rome', 'Baghdad', 'Moscow', 'Seattle', 'Chicago', 'New York', 'Montreal', 'Istanbul', 'Bombay', 'Manila', 'Capetown']
# Final Distance: 548.0
# [21,
#  0,
#  16,
#  19,
#  7,
#  18,
#  15,
#  24,
#  26,
#  11,
#  9,
#  28,
#  14,
#  8,
#  29,
#  27,
#  13,
#  3,
#  6,
#  22,
#  4,
#  25,
#  20,
#  23,
#  10,
#  5,
#  1,
#  17,
#  2,
#  12]
